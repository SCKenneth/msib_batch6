# %%
# !pip install plotly==5.20.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 28.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.15.0
#     Uninstalling plotly-5.15.0:
#       Successfully uninstalled plotly-5.15.0
# ...

# %%
import plotly.express as px
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv("/content/used_car_data_new.csv")

# %%
ds.head()
# Out:
#    id_ucd      id_merk                    type          model          color  \
# 0       1        Mazda                    CX-5            SUV          Hitam
# 1      44        Mazda               3 5 HB 6E        MINIBUS  HITAM METALIK
# 2     160        Mazda                    CX 5            SUV   PUIH METALIK
# 3      90      Hyundai                    I-20        MINIBUS          MERAH
# 4      25  Range Rover  RANGE ROVER 4.2L V8 AT  JEEP S.C.HDTP          HITAM
#
#    year  id_transmission id_fuel_type  door  cylinder_size  ...   stnk_date  \
# 0  2016                2     Gasoline     5           2500  ...   3/23/2024
# 1  2016                2     Gasoline     5           1998  ...  10/22/2023
# 2  2014                2     Gasoline     5           2498  ...  10/20/2024
# 3  2010                2     Gasoline     5           1396  ...  11/16/2025
# 4  2007                2     Gasoline     5           4187  ...  10/16/2024
#
# ...

# %%
ds.isnull().sum()
# Out:
# id_ucd                0
# id_merk               0
# type                  0
# model                 0
# color                 0
# year                  0
# id_transmission       0
# id_fuel_type          0
# door                  0
# cylinder_size         0
# cylinder_total        0
# turbo                 0
# mileage               0
# license_plate         0
# price_cash            0
# price_credit          0
# nilai_jual_pkb        1
# pkb_pokok             4
# stnk_date             1
# levy_date             1
# swdkllj               4
# total_levy            4
# showroom_name         0
# showroom_location     0
# showroom_regency      0
# photo_1              13
# created_at            0
# updated_at            0
# dtype: int64

# %%
ds = ds.dropna()

# %%
ds.isnull().sum()
# Out:
# id_ucd               0
# id_merk              0
# type                 0
# model                0
# color                0
# year                 0
# id_transmission      0
# id_fuel_type         0
# door                 0
# cylinder_size        0
# cylinder_total       0
# turbo                0
# mileage              0
# license_plate        0
# price_cash           0
# price_credit         0
# nilai_jual_pkb       0
# pkb_pokok            0
# stnk_date            0
# levy_date            0
# swdkllj              0
# total_levy           0
# showroom_name        0
# showroom_location    0
# showroom_regency     0
# photo_1              0
# created_at           0
# updated_at           0
# dtype: int64

# %%
sns.pairplot(ds)

# %%
ds.columns
# Out:
# Index(['id_ucd', 'id_merk', 'type', 'model', 'color', 'year',
#        'id_transmission', 'id_fuel_type', 'door', 'cylinder_size',
#        'cylinder_total', 'turbo', 'mileage', 'license_plate', 'price_cash',
#        'price_credit', 'nilai_jual_pkb', 'pkb_pokok', 'stnk_date', 'levy_date',
#        'swdkllj', 'total_levy', 'showroom_name', 'showroom_location',
#        'showroom_regency', 'photo_1', 'created_at', 'updated_at'],
#       dtype='object')

# %%
ds.id_merk.unique()
# Out:
# array(['Mazda', 'Hyundai', 'Range Rover', 'Jeep', 'Jaguar', 'VW',
#        'Porsche', 'Lexus', 'Audi', 'BMW', 'Mercedes Benz', 'Datsun',
#        'Wuling', 'Nissan', 'Suzuki', 'Mitsubishi', 'Daihatsu', 'Honda',
#        'Toyota', 'Isuzu'], dtype=object)

# %%
 fig = px.histogram(ds, x="id_merk",
                     labels= {"id_merk": "Merk"},
                     title= "Merk Mobil",
                     color_discrete_sequence=["red"])
 fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
ds.corr()
# Out:
# <ipython-input-15-31b754434382>:1: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#                    id_ucd      year  id_transmission      door  cylinder_size  \
# id_ucd           1.000000  0.154405         0.048166 -0.018267      -0.109399
# year             0.154405  1.000000        -0.121440  0.162064      -0.421134
# id_transmission  0.048166 -0.121440         1.000000 -0.059909       0.228375
# door            -0.018267  0.162064        -0.059909  1.000000      -0.226385
# cylinder_size   -0.109399 -0.421134         0.228375 -0.226385       1.000000
# cylinder_total  -0.203201 -0.440808         0.073994 -0.074348       0.641086
# turbo            0.077084  0.045293         0.011191 -0.015369       0.294584
# mileage         -0.127295 -0.445187        -0.112252  0.129635       0.003027
# ...

# %%
plt.figure(figsize=(18,18))
sns.heatmap(ds.corr(), cmap= "BuGn", annot=True)
# Out:
# <ipython-input-16-3f2cb3015425>:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
# <Axes: >

# %%
ds.dtypes
# Out:
# id_ucd                 int64
# id_merk               object
# type                  object
# model                 object
# color                 object
# year                   int64
# id_transmission        int64
# id_fuel_type          object
# door                   int64
# cylinder_size          int64
# cylinder_total         int64
# turbo                  int64
# mileage                int64
# license_plate         object
# price_cash             int64
# price_credit           int64
# nilai_jual_pkb       float64
# pkb_pokok            float64
# stnk_date             object
# levy_date             object
# swdkllj              float64
# total_levy           float64
# showroom_name         object
# showroom_location     object
# showroom_regency      object
# photo_1               object
# created_at            object
# updated_at            object
# dtype: object

# %%
ds.columns
# Out:
# Index(['id_ucd', 'id_merk', 'type', 'model', 'color', 'year',
#        'id_transmission', 'id_fuel_type', 'door', 'cylinder_size',
#        'cylinder_total', 'turbo', 'mileage', 'license_plate', 'price_cash',
#        'price_credit', 'nilai_jual_pkb', 'pkb_pokok', 'stnk_date', 'levy_date',
#        'swdkllj', 'total_levy', 'showroom_name', 'showroom_location',
#        'showroom_regency', 'photo_1', 'created_at', 'updated_at'],
#       dtype='object')

# %%
ds_new = pd.get_dummies(ds, columns= ['id_merk', 'type', 'model', 'color', 'id_fuel_type',
                                     'license_plate', 'nilai_jual_pkb', 'pkb_pokok', 'stnk_date', 'levy_date',
                                     'swdkllj', 'total_levy', 'showroom_name', 'showroom_location',
                                     'showroom_regency', 'photo_1', 'created_at', 'updated_at'])

# %%
ds_new.head()
# Out:
#    id_ucd  year  id_transmission  door  cylinder_size  cylinder_total  turbo  \
# 1      44  2016                2     5           1998               4      0
# 2     160  2014                2     5           2498               4      0
# 3      90  2010                2     5           1396               4      0
# 4      25  2007                2     5           4187               8      0
# 5     135  2014                2     5           2994               4      0
#
#    mileage  price_cash  price_credit  ...  updated_at_4/7/2023 14:44  \
# 1    55000   340000000     360000000  ...                          0
# 2    95000   287000000     277000000  ...                          0
# 3   100000    85000000     100000000  ...                          0
# 4       95   535000000     550000000  ...                          0
# 5    43000  1250000000    1150000000  ...                          0
#
#    updated_at_4/7/2023 14:49  updated_at_4/7/2023 14:55  \
# ...

# %%
x = ds_new.drop("price_cash", axis=1)
y = ds_new["price_cash"]

# %%
x
# Out:
#      id_ucd  year  id_transmission  door  cylinder_size  cylinder_total  \
# 1        44  2016                2     5           1998               4
# 2       160  2014                2     5           2498               4
# 3        90  2010                2     5           1396               4
# 4        25  2007                2     5           4187               8
# 5       135  2014                2     5           2994               4
# ..      ...   ...              ...   ...            ...             ...
# 196     102  2018                2     5           1987               4
# 197     138  2012                2     5           1998               4
# 199     170  2015                2     5           2494               4
# 200     179  2012                1     5           2494               4
# 201     185  2013                2     5           2494               4
#
#      turbo  mileage  price_credit  id_merk_Audi  ...  \
# ...

# %%
x = np.array(x)
y = np.array(y)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,
                                                    random_state=1)

# %% [markdown]
# LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()
linear_model.fit(x_train, y_train)
linear_model.score(x_test, y_test)
# Out:
# 0.7915967164436091

# %% [markdown]
# DECISION TREE REGRESSION

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dec_model = DecisionTreeRegressor()
dec_model.fit(x_train, y_train)
dec_model.score(x_test, y_test)
# Out:
# 0.878456796130295

# %% [markdown]
# RANDOM FOREST REGRESSION

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_model = RandomForestRegressor()
random_model.fit(x_train, y_train)
random_model.score(x_test, y_test)
# Out:
# 0.85623606668832

# %% [markdown]
# XGBoost Regression

# %%
from xgboost import XGBRegressor

# %%
xgb_model = XGBRegressor()
xgb_model.fit(x_train, y_train)
xgb_model.score(x_test, y_test)
# Out:
# 0.863032806421889
